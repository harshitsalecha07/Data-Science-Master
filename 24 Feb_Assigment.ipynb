# %%
##Q1. List any five functions of the pandas library with execution.

# %%
data={'City':['J','D','M','P','B'],'Population':[123,532,567,321,235]}

# %%
import pandas as pd

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#   City  Population
# 0    J         123
# 1    D         532
# 2    M         567
# 3    P         321
# 4    B         235

# %%
##head()
df1.head(2)
# Out:
#   City  Population
# 0    J         123
# 1    D         532

# %%
##tail()
df1.tail(1)
# Out:
#   City  Population
# 4    B         235

# %%
##Describe
df1.describe()
# Out:
#        Population
# count    5.000000
# mean   355.600000
# std    190.821382
# min    123.000000
# 25%    235.000000
# 50%    321.000000
# 75%    532.000000
# max    567.000000

# %%
##Cumsum()
df1['Population'].cumsum()
# Out:
# 0     123
# 1     655
# 2    1222
# 3    1543
# 4    1778
# Name: Population, dtype: int64

# %%
##loc
df1.loc[0:2]
# Out:
#   City  Population
# 0    J         123
# 1    D         532
# 2    M         567

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
data2={'A':[5,6,7],'B':[6,2,5],'C':[7,6,8]}

# %%
df2=pd.DataFrame(data2)

# %%
df2
# Out:
#    A  B  C
# 0  5  6  7
# 1  6  2  6
# 2  7  5  8

# %%
df2.reindex([1,3,5])
# Out:
#      A    B    C
# 1  6.0  2.0  6.0
# 3  NaN  NaN  NaN
# 5  NaN  NaN  NaN

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console. For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.

# %%
df3=pd.DataFrame({"Values":[100,3,6,3,2,50]})

# %%
for i in df3.items():
    a=list(i)
    print("The sum of first three values is : ",a[1][0]+a[1][1]+a[1][2])
# Out:
# The sum of first three values is :  109

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df4=pd.DataFrame({"Text":['Python is a high-level, general-purpose programming language.','The name of this course is Data Science Masters','This course is very good for all types of user','Data Science is best course for todays aspirant']})

# %%
df4['Word_Count']=df4['Text'].apply(lambda x:len(x.split()))
df4
# Out:
#                                                 Text  Word_Count
# 0  Python is a high-level, general-purpose progra...           7
# 1    The name of this course is Data Science Masters           9
# 2     This course is very good for all types of user          10
# 3    Data Science is best course for todays aspirant           8

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# DataFrame.size represents the size of the DataFrame where DataFrame.shape represents the shapes of the DataFrame in the tuple form.

# %%
data3={"a":[1,2,3,4,5],"b":[6,7,8,9,10],"c":["H","A","R","S","H"],"d":[11,12,13,"A","P"]}

# %%
df5=pd.DataFrame(data3)

# %%
df5
# Out:
#    a   b  c   d
# 0  1   6  H  11
# 1  2   7  A  12
# 2  3   8  R  13
# 3  4   9  S   A
# 4  5  10  H   P

# %%
df5.shape
# Out:
# (5, 4)

# %%
df5.size
# Out:
# 20

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %%
##pd.read_excel is the pandas function which is used to read an excel file. for example
df6=pd.read_excel("Book1.xlsx")

# %%
df6
# Out:
#     House Age (years)  Distance to Station (meters)  Price per Square Foot  \
# 0                32.0                      84.87882                   75.8
# 1                19.5                     306.59470                   84.4
# 2                13.3                     561.98450                   94.6
# 3                13.3                     561.98450                  109.6
# 4                 5.0                     390.56840                   86.2
# 5                 7.1                    2175.03000                   64.2
# 6                34.5                     623.47310                   80.6
# 7                20.3                     287.60250                   93.4
# 8                31.7                    5512.03800                   37.6
# 9                17.9                    1783.18000                   44.2
# 10               34.8                     405.21340                   82.8
# ...

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
a='username@domain.com'

# %%
lst=a.split('@')

# %%
lst[0]
# Out:
# 'username'

# %%
def username(x):
    lst=x.split('@')
    return lst[0]

# %%
df7=pd.DataFrame({'Email-id':["XYZ@ABC.com","PQR@ABC.com","MNO@ABC.com","XYZ@PPQ.com","PPWQ@MMMA.com"]})

# %%
df7
# Out:
#         Email-id
# 0    XYZ@ABC.com
# 1    PQR@ABC.com
# 2    MNO@ABC.com
# 3    XYZ@PPQ.com
# 4  PPWQ@MMMA.com

# %%
df7['User Name']=df7['Email-id'].apply(username)

# %%
df7
# Out:
#         Email-id User Name
# 0    XYZ@ABC.com       XYZ
# 1    PQR@ABC.com       PQR
# 2    MNO@ABC.com       MNO
# 3    XYZ@PPQ.com       XYZ
# 4  PPWQ@MMMA.com      PPWQ

# %%
'''Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
function should return a new DataFrame that contains only the selected rows.
For example, if df contains the following values:
A B C
0 3 5 1
1 8 2 7
2 6 9 4
3 2 3 5
4 9 1 2
Your function should select the following rows: A B C
1 8 2 7
4 9 1 2
The function should return a new DataFrame that contains only the selected rows.'''
# Out:
# "Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects\nall rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The\nfunction should return a new DataFrame that contains only the selected rows.\nFor example, if df contains the following values:\nA B C\n0 3 5 1\n1 8 2 7\n2 6 9 4\n3 2 3 5\n4 9 1 2\nYour function should select the following rows: A B C\n1 8 2 7\n4 9 1 2\nThe function should return a new DataFrame that contains only the selected rows."

# %%
df8=pd.DataFrame({'A':[3,8,6,2,9],'B':[5,2,11,3,1],"C":[1,7,4,5,2]})

# %%
df8
# Out:
#    A   B  C
# 0  3   5  1
# 1  8   2  7
# 2  6  11  4
# 3  2   3  5
# 4  9   1  2

# %%
def select(df8):
    selected_Row=df8[(df8['A']>5) & (df8['B']<10)]
    return selected_Row

# %%
selected=select(df8)
print(selected)
# Out:
#    A  B  C
# 1  8  2  7
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
df9=pd.DataFrame({'Values':[6,34,6,3,2,56,7,4,5,8,45,3,2,4,6,8,4,2,5,7,89,5,3,5,7,3,5,7,4]})

# %%
df9['Values'].mean()
# Out:
# 11.89655172413793

# %%
df9['Values'].median()
# Out:
# 5.0

# %%
df9['Values'].std()
# Out:
# 19.642055514318915

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
data=pd.date_range(start='06-06-2023', end='20-06-2023')
sales=[232,542,635,356,364,66,843,685,367,357,325,732,678,874,78]
df10=pd.DataFrame({'Date':data,'Sales':sales})
# Out:
# /tmp/ipykernel_98/2763686106.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data=pd.date_range(start='06-06-2023', end='20-06-2023')

# %%
df10['Moving Average']=df10['Sales'].rolling(window=7).mean()

# %%
df10
# Out:
#          Date  Sales  Moving Average
# 0  2023-06-06    232             NaN
# 1  2023-06-07    542             NaN
# 2  2023-06-08    635             NaN
# 3  2023-06-09    356             NaN
# 4  2023-06-10    364             NaN
# 5  2023-06-11     66             NaN
# 6  2023-06-12    843      434.000000
# 7  2023-06-13    685      498.714286
# 8  2023-06-14    367      473.714286
# 9  2023-06-15    357      434.000000
# 10 2023-06-16    325      429.571429
# 11 2023-06-17    732      482.142857
# 12 2023-06-18    678      569.571429
# 13 2023-06-19    874      574.000000
# 14 2023-06-20     78      487.285714

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the modified DataFrame.

# %%
df11=pd.DataFrame({'Date': pd.date_range(start='2023-02-01',end='2023-04-05')})

# %%
df11['Weekday']=df11['Date'].dt.day_name()

# %%
df11
# Out:
#          Date    Weekday
# 0  2023-02-01  Wednesday
# 1  2023-02-02   Thursday
# 2  2023-02-03     Friday
# 3  2023-02-04   Saturday
# 4  2023-02-05     Sunday
# ..        ...        ...
# 59 2023-04-01   Saturday
# 60 2023-04-02     Sunday
# 61 2023-04-03     Monday
# 62 2023-04-04    Tuesday
# 63 2023-04-05  Wednesday
#
# [64 rows x 2 columns]

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
df12=pd.DataFrame({'Date': pd.date_range(start='2023-01-01',end='2023-01-31')})

# %%
df12['Year']=df12['Date'].dt.year

# %%
df12['Month']=df12['Date'].dt.month

# %%
df12['Day Date']=df12['Date'].dt.day

# %%
df12['Week Day']=df12['Date'].dt.day_name()

# %%
df12
# Out:
#          Date  Year  Month  Day Date   Week Day
# 0  2023-01-01  2023      1         1     Sunday
# 1  2023-01-02  2023      1         2     Monday
# 2  2023-01-03  2023      1         3    Tuesday
# 3  2023-01-04  2023      1         4  Wednesday
# 4  2023-01-05  2023      1         5   Thursday
# 5  2023-01-06  2023      1         6     Friday
# 6  2023-01-07  2023      1         7   Saturday
# 7  2023-01-08  2023      1         8     Sunday
# 8  2023-01-09  2023      1         9     Monday
# 9  2023-01-10  2023      1        10    Tuesday
# 10 2023-01-11  2023      1        11  Wednesday
# 11 2023-01-12  2023      1        12   Thursday
# 12 2023-01-13  2023      1        13     Friday
# 13 2023-01-14  2023      1        14   Saturday
# 14 2023-01-15  2023      1        15     Sunday
# 15 2023-01-16  2023      1        16     Monday
# 16 2023-01-17  2023      1        17    Tuesday
# 17 2023-01-18  2023      1        18  Wednesday
# 18 2023-01-19  2023      1        19   Thursday
# ...
